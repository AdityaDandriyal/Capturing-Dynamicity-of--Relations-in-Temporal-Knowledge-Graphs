# %%
# Specify the file path
file_path = '/content/drive/MyDrive/hyte_entity2id.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# <Athletic_Park_(Vancouver)>	7269	1913-##-##	####-##-##
# <Aro_Tolbukhin._En_la_mente_del_asesino>	9688	2002-11-08	####-##-##
# <Getafe_CF>	4946	1983-07-08	####-##-##
# <Südtiroler_Sparkasse_–_Cassa_di_Risparmio_di_Bolzano>	6803	1854-##-##	####-##-##
# <Fortuna_Düsseldorf>	5131	1895-05-05	####-##-##
# <Jane_Bryan>	3605	1918-06-11	2009-04-08
# <Jean-Louis_Borloo>	2833	1951-04-07	####-##-##
# <Netanya>	292	1929-02-18	####-##-##
# <University_of_Adelaide>	3895	1874-##-##	####-##-##
# <Granada_CF>	4341	1931-04-14	####-##-##
# <Daigaku_Honyaku_Center>	6523	####-##-##	####-##-##
# <Albuquerque,_New_Mexico>	336	1706-##-##	####-##-##
# <London_Transport_Board>	6377	1963-##-##	####-##-##
# <Robert_Lešnik>	9377	1971-##-##	####-##-##
# <A.C._Reggiana_1919>	5139	1919-##-##	####-##-##

# %%
def extract_first_two_elements(input_file_path, output_file_path):
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    with open(output_file_path, 'w') as output_file:
        for line in lines:
            # Split the line by tabs
            elements = line.strip().split('\t')

            # Extract the first two elements
            first_two_elements = '\t'.join(elements[:2])

            # Write to the output file
            output_file.write(first_two_elements + '\n')

# Example usage
input_file_path = '/content/drive/MyDrive/hyte_entity2id.txt'            # Replace with your actual input file path
output_file_path = '/content/drive/MyDrive/entity2id.txt'           # Replace with your desired output file path

extract_first_two_elements(input_file_path, output_file_path)

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/entity2id.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# <Athletic_Park_(Vancouver)>	7269
# <Aro_Tolbukhin._En_la_mente_del_asesino>	9688
# <Getafe_CF>	4946
# <Südtiroler_Sparkasse_–_Cassa_di_Risparmio_di_Bolzano>	6803
# <Fortuna_Düsseldorf>	5131
# <Jane_Bryan>	3605
# <Jean-Louis_Borloo>	2833
# <Netanya>	292
# <University_of_Adelaide>	3895
# <Granada_CF>	4341
# <Daigaku_Honyaku_Center>	6523
# <Albuquerque,_New_Mexico>	336
# <London_Transport_Board>	6377
# <Robert_Lešnik>	9377
# <A.C._Reggiana_1919>	5139

# %%
def create_mapping(input_file_path):
    mapping = {}

    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    for line in lines:
        # Split the line by tabs
        elements = line.strip().split('\t')

        # Extract the integer and name
        integer = int(elements[1])
        name = elements[0].replace('<', '').replace('>', '')

        # Add to the mapping
        mapping[integer] = name

    return mapping

# Example usage
input_file_path = '/content/drive/MyDrive/entity2id.txt'  # Replace with your actual input file path

entity_mapping = create_mapping(input_file_path)

# Print or use the resulting mapping as needed
print("Mapping of integers to names:")
for integer, name in entity_mapping.items():
    print(f"{integer}: {name}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 42: Choi_Won-young
# 7710: Brazilian_Socialist_Party
# 7153: Nick_Jr._(CIS)
# 7522: Robert_Best_(politician)
# 6160: K._S._L._Swamy
# 9137: Paavo_Nurmi
# 7754: Roy_Jenkins
# 2803: Jon_Cryer
# 5456: Nick_Saban
# 477: Lucille_La_Verne
# 8953: The_34-Ton_Bat
# 7081: Foxboro_Stadium
# 3819: Inter-American_Tropical_Tuna_Commission
# 8127: Arthur_Hailey
# 3681: Éamon_Zayed
# 10027: Walter_Landor
# 7115: Astral_Media
# 1371: Troian_Bellisario
# 2943: Chaya_Singh
# 340: Shōhei_Ōoka
# 5002: Henrik_Ojamaa
# 4347: Ukraine_national_under-21_football_team
# 7558: Federico_Fellini
# 10330: Gordon_Bess
# 3790: Frances_Howard_(actress)
# 4552: Girona_FC
# 7606: Zdeněk_Fierlinger
# 796: Bebe_Daniels
# 4668: Kerem_Demirbay
# 2951: Randy_Savage
# 2460: Choy_Kan-pui
# 2934: Angelino_Alfano
# 428: Marylebone
# 10398: A_Boy_Named_Sue
# 8573: Adolphe_Sax
# 2440: Renan_Calheiros
# 1415: Meshach_Taylor
# 3469: George_Hamilton_(actor)
# 10542: Shigeru_Uehara
# 5360: Balzan_Prize
# 6163: Judith_Barrett
# 2590: Kate_Jackson
# 10031: De_kellner_en_de_levenden
# 205: Wiesbaden
# 719: Duncan_Preston
# 4871: Sheffield_Wednesday_F.C.
# 1950: Alex_Campbell_(golfer)
# 10528: Mitchel_Musso
# 361: Flushing,_Queens
# 1809: Paul_R._Ehrlich
# 10451: Raising_Victor_Vargas
# 4228: University_of_Hamburg
# 10297: The_Guard_(2011_film)
# 9352: Dexterity_(video_game)
# 7957: Christophe_Beck
# 5594: IEEE_Fellow
# 8793: Withers_Building
# 7343: PeopleSoft
# 2992: Ashraf_Sinclair
# 2486: Whitley_Strieber
# 2872: Tina_Sinatra
# 7203: British_Aerospace
# 9852: Janet_Fielding
# 4481: Charlton_Athletic_F.C.
# 8463: Kia_K9
# 5205: John_Steinbeck
# 7955: Alone_in_the_Dark_(2008_video_game)
# 4792: S.S._Lazio
# 1761: Dena_Grayson
# 2401: Susan_Harris
# 3117: Frazier_Glenn_Miller_Jr.
# 4845: FC_Zorya_Luhansk
# 5081: S.C._Espinho
# 3394: Kim_Kimoon
# 3459: Hong_Eun-hee
# 10340: James_Brown_Lord
# 4759: FC_Spartak_Moscow
# 4152: National_Science_Foundation
# 1032: Fall_River,_Massachusetts
# 8971: T.A._Welsh
# 4188: Uppsala_University
# 8239: Firaxis_Games
# 6944: Pearson_Television
# 2972: James_J._Wynne
# 4114: Joseph_Zachary
# 6251: Florence_Marly
# 7532: Benjamin_Butler
# 6839: TV_Syd
# 4073: Royal_Dutch_Shell
# 4066: Stony_Brook_University
# 10023: Mark_Marderosian
# 2815: Geraldine_Doogue
# 1903: Mike_Comrie
# 6258: Billy_Rose
# 5697: Charles_Coulson
# 8605: Hiro_Mizushima
# 5637: Arnold_Sommerfeld
# 3736: Lee_Farr
# 4083: University_of_California,_Los_Angeles
# 4847: Beşiktaş_J.K.
# 2331: Noa_Tishby
# 9398: YoWorld
# 9970: Haciendas_de_Jalisco_y_Aledaños_(1506–1821)
# 10402: Koodevide
# 1552: Frank_O'Hara
# 1980: Kenneth_G._Wilson
# 10432: Doing_Hard_Time
# 6810: Confluence_Queens_F.C.
# 3005: Josh_Dallas
# 1979: David_McLaren_(politician)
# 10337: Patrick_Villiers_Farrow
# 2500: Kristal_Tin
# 6641: Gorgon_gas_project
# 4494: Birmingham_City_F.C.
# 1533: Elizabeth_Warren
# 1095: Nicholas_Robinson_(historian)
# 6542: Sumitomo_Group
# 9611: Man_Walks_Into_a_Room
# 4924: Carlisle_United_F.C.
# 2427: Elizabeth_Berridge_(actress)
# 1001: Barbara_Cooney
# 8101: Ola_Bola
# 9427: Think_Like_a_Dinosaur
# 1692: Lord_Byron
# 3084: Hanna_Scheuring
# 2350: Malcolm_X
# 4766: Djurgårdens_IF_Fotboll
# 5588: Robert_Andrews_Millikan
# 2688: Pasadena,_California
# 8720: Bobby_Weed
# 147: Seattle
# 874: Pia_Zadora
# 8565: Joseph_Had_a_Little_Overcoat
# 6093: Julie_Condra
# 6639: RAF_Breighton
# 4673: Nikica_Jelavić
# 7620: Wäinö_Aaltonen
# 4515: C.S._Marítimo
# 2436: Lea_Grundig
# 5479: Henry_Draper_Medal
# 1683: Yoyo_Chen
# 5564: Adrian_Bird
# 9832: Agnieszka_Holland
# 4387: Cardiff_City_F.C.
# 4136: Peking_University
# 6914: Anheuser-Busch
# 1078: Josh_Charles
# 2552: Elizabeth_McGovern
# 2047: Anne_Flournoy
# 2875: Malibu,_California
# 1141: Riccardo_Giacconi
# 6807: UBI_Banca
# 766: Yvette_Fielding
# 822: Hilde_Neumann
# 2026: Sibylle_Bergemann
# 7550: Charles_Maley
# 673: W._V._D._Hodge
# 7145: Orion_International
# 2011: Ernie_Kovacs
# 5879: Mira_Nair
# 9075: A_Swift_Pure_Cry
# 1075: Susan_Peters
# 8943: The_Death_of_the_Heart
# 296: Miranda_Kerr
# 1367: Gregg_Allman
# 476: Tobey_Maguire
# 6470: CBS_Radio
# 2515: David_F._Ford
# 2585: Julian_Cheung
# 4702: Boavista_F.C.
# 741: Jane_Alexander
# 1296: John_M._Read
# 10233: Coat_of_arms_of_Ukraine
# 3273: Janice_Filmon
# 1192: Stephen_Moorbath
# 581: Mark_Oaten
# 8024: The_Navy_Lark
# 10069: Battle_Cry_of_Freedom_(book)
# 4591: S.C._Salgueiros
# 5689: Salem_Prize
# 2911: John_Chanter
# 560: William_Travilla
# 713: David_Sankoff
# 448: Brimah_Razak
# 994: Archdale_Parkhill
# 7136: Letzigrund
# 6952: Sovcomflot
# 4325: FC_Olimpik_Donetsk
# 6976: Godolphin_Stables
# 10345: Thomas_Minton
# 992: Chikki_Panday
# 342: Málaga
# 3149: Dan_Finnerty
# 6551: Rai_Way
# 2865: Nice
# 8241: LILO_(boot_loader)
# 10473: Hooray_for_Love_(TV_series)
# 3465: Jada_Pinkett_Smith
# 9471: Stratton_Hammon
# 6249: Carla_Del_Poggio
# 1091: Joseph_S._Cabot
# 10545: Wooden_Foot_Cops_on_the_Highway
# 8629: Jaws_(ride)
# 6791: Goodreads
# 276: Lev_Landau
# 1365: Ann_Druyan
# 3854: John_Wilson_Moore
# 4641: Tamworth_F.C.
# 931: Nancy_Meyers
# 6310: James_Cruze
# 4646: Matthew_Upson
# 149: St._Louis
# 5934: Theodore_von_Karman_Medal
# 762: Łódź
# 609: Mike_Hookem
# 10527: Jean-Baptiste_Bethune
# 3371: Curtis_T._McMullen
# 3374: Conor_Clifford
# 5555: Daniel_C._Drucker
# 4709: Bristol_City_F.C.
# 2847: Turgut_Özal
# 2756: Juan_Sordo_Madaleno
# 5810: Simon_Conway_Morris
# 3072: Mikhail_Shifman
# 136: Ichirō_Ozawa
# 5793: Mikhail_Chumakov
# 3587: Alexei_Starobinsky
# 799: Lars_Ahlfors
# 7243: Bright_House_Networks
# 843: Augusta,_Georgia
# 3751: Tina_Lenert
# 3807: Cynthia_Rhodes
# 4193: Catherine_Hakim
# 2671: Hank_Azaria
# 7173: CKNC-TV
# 80: Kurt_Russell
# 3336: Leroy_Hood
# 4687: AS_Monaco_FC
# 1629: Suchitra_Krishnamoorthi
# 5393: Harold_Jeffreys
# 5894: Marconi_Prize
# 1302: Paul_Wesley
# 9830: Susan_Maxman
# 4363: Darlington_F.C.
# 6876: Broadway_Centrum
# 3356: Steffi_Duna
# 7583: Henry_Clay
# 10093: Hopperstad_Stave_Church
# 5978: Ry_Nikonova
# 4302: James_McNulty_(footballer)
# 5227: Crafoord_Prize
# 2197: James_Goldman
# 7041: CIÉ
# 816: Robert_Ogden_Doremus
# 4374: Inter_Milan
# 4200: Kyrgyz_National_University
# 10506: Dik_Browne
# 9234: Are_You_Being_Served?
# 4236: Spain_national_under-17_football_team
# 8094: Miss_Julie
# 6201: Bob_Thiele
# 7048: Trans_Corp
# 8135: Crash_Bandicoot
# 1500: Jin_Yan
# 6943: RTL_Group
# 5872: Henry_Eyring_(chemist)
# 8896: Philip_Larkin
# 9244: BMW_7_Series_(F01)
# 9021: The_Cat_Who_Came_for_Christmas
# 127: Athens
# 4964: Dani_Osvaldo
# 5207: Dick_MacPherson
# 3656: Jeffrey_W._Greenberg
# 9588: Hurd_Hatfield
# 7292: Blackwater_(Isle_of_Wight)_railway_station
# 9116: The_Revenant_(novel)
# 4051: Kessler_Institute_for_Rehabilitation
# 7840: Francisco_Tatad
# 1756: John_Hopkins_(writer)
# 7849: Ian_Wrigglesworth
# 10565: Gilbert_Stanley_Underwood
# 4881: Shane_Smeltz
# 2682: Necmettin_Erbakan
# 3324: America_Ferrera
# 4863: Oxford_United_F.C.
# 4507: Vadym_Milko
# 3053: Hal_Mohr
# 7982: Dream_House_(game_show)
# 2297: Norman_Maurer
# 10362: The_Flick
# 8610: Eduard_Lazarev
# 7682: Unity_(Latvian_political_party)
# 328: Orange,_New_Jersey
# 7205: Edward_Stanley,_17th_Earl_of_Derby
# 2962: Gerald_Walpin
# 4898: Djamel_Abdoun
# 4700: CE_L'Hospitalet
# 10459: Desmond_Morris
# 2417: Kensington_Palace
# 4948: Oleksiy_Kurilov
# 5767: Narmad_Suvarna_Chandrak
# 377: Griffin_Dunne
# 3585: Eric_H._Davidson
# 4354: Manchester_United_F.C.
# 9812: Jean-Claude_van_Itallie
# 4291: Portugal_national_under-20_football_team
# 4172: Hamilton_College_(New_York)
# 4789: France_national_under-17_football_team
# 3962: Technische_Universität_Darmstadt
# 4746: Henri_Anier
# 1072: José_Luis_Morales_Martín
# 10153: Westwood_Studios
# 6365: Eni
# 5206: Nobel_Prize_in_Literature
# 972: Jacques_Goudstikker
# 2472: Jair_Bolsonaro
# 1319: Willem-Alexander_of_the_Netherlands
# 1480: Kim_McLagan
# 2597: Maxine_Singer
# 5375: AIA_Gold_Medal
# 7715: UK_Independence_Party
# 5773: André_Michel_Lwoff
# 1687: Paul_Wong_(musician)
# 4643: João_Paulo_Neto_Martins
# 4250: PAOK_FC
# 2053: Ayrshire
# 7363: DESFA
# 6102: Mao_Zedong
# 3749: Mark_Meily
# 5808: V._M._Goldschmidt_Award
# 430: Story_Musgrave
# 9059: F._A._de_Meuron
# 9210: Luvos
# 4223: Susan_Golden
# 7489: West_Los_Angeles
# 4548: Enzo_Maresca
# 9013: Mabel_Lucie_Attwell
# 8544: Worcester_Country_Club
# 9964: Silverado_Resort,_California
# 7880: Abraham_Colfe
# 10294: Paul-James_Corrigan
# 9968: John_Elder_Robison
# 6581: On-Media
# 8909: Luv_Me,_Luv_Me
# 5533: Donald_Henderson
# 6599: Comet_Group
# 2262: Christian_Finnegan
# 9338: Bob_Kushell
# 3746: Luise_Rainer
# 7924: Sexual_Perversity_in_Chicago
# 4064: Flinders_University
# 6955: Billy_Gibson_(boxing)
# 6428: Independent_business
# 3660: Kerry_Bentivolio
# 7255: Mutual_Broadcasting_System
# 227: Hannah_Storm
# 5908: David_Jack_(scientist)
# 7983: The_Blue_Bird_(play)
# 4265: Wellington_Phoenix_FC
# 7310: Radio_Caroline_(New_Zealand)
# 8452: Sink_the_Belgrano!
# 2343: Darryl_Rouson
# 6222: Willis_Hall
# 9669: The_Love_Song_of_J._Alfred_Prufrock
# 10190: Rex_Shelley
# 2150: Dede_Scozzafava
# 7591: John_McEnery_(Louisiana)
# 562: Tony_Barwick
# 5212: Fermat_Prize
# 5719: Harold_Pinter
# 1317: Eddie_Edwards_(wrestler)
# 5346: Claude_Cohen-Tannoudji
# 9884: Viet_Rock
# 7380: St._Petersburg,_Florida
# 8774: John_Langalibalele_Dube
# 9382: Gravity_Ghost
# 10475: Zion_Church_(Rome,_New_York)
# 7035: Banco_Espírito_Santo
# 333: Tyson_Kidd
# 9512: The_Recognitions
# 6119: Valéry_Giscard_d'Estaing
# 4323: Portugal_national_under-17_football_team
# 8932: El_Chapulín_Colorado
# 6162: Olaf_Pooley
# 6773: Baseball_Ground
# 5162: Charles_Stark_Draper_Prize
# 71: Cambridge
# 7211: Rhode_Island_Auditorium
# 6149: Mary_Eaton
# 10239: Richard_Philipp
# 8707: Osborn_Engineering
# 403: Aline_Caroline_de_Rothschild
# 6538: Studio_100
# 8029: Hedwiga_Reicher
# 5806: Shiing-Shen_Chern
# 1256: Pamela_Tiffin
# 4608: Ciarán_Toner
# 3502: Edgardo_Vega_Yunqué
# 6212: George_Lucas
# 4068: University_of_Missouri
# 8660: Hit_&_Miss
# 2028: Fran_Jeffries
# 6805: Corus_Entertainment
# 8450: Sebastiane
# 8989: Napster
# 857: Justin_Trudeau
# 1816: Gordon_S._Wood
# 6156: Fern_Andra
# 2218: Joe_Stillman
# 3628: Susan_Penhaligon
# 4177: California_Institute_for_Regenerative_Medicine
# 7755: Elijah_Carey
# 7338: Urban_Transit_Authority
# 4094: University_of_Illinois_system
# 1868: Kambri_Crews
# 10583: Thakurmar_Jhuli
# 10032: Berlin_Dialogue_for_Orchestra
# 4940: Rafael_García_García
# 330: New_Delhi
# 9877: Capcom
# 10504: Matthew_Ellison_Hadfield
# 3434: Fraser_Stoddart
# 2200: Marion_Byron
# 10558: Lexus_GS
# 8281: William_D._Cohan
# 9090: Richard_Tanne
# 6951: Government_of_Russia
# 4081: Long-Term_Capital_Management
# 6609: Emerson_Radio
# 6208: Debrah_Farentino
# 2661: Corbin_Bleu
# 7576: P._T._Barnum
# 5157: Norman_Borlaug
# 875: Noel_Blanc
# 3882: Timothy_Killeen_(academic)
# 7492: Stanko_Todorov
# 383: Andrew_Stevens
# 10185: Overseas_Passenger_Terminal
# 7555: Thaddeus_Stevens
# 6608: Panasonic
# 2898: Vanda_Hybnerová
# 5300: EMBO_Gold_Medal
# 7894: Badai_Pasti_Berlalu_(film)
# 8465: Church_of_St_Michael,_Princetown
# 9745: Palazzo_Parisio_(Valletta)
# 5314: Dominic_Joyce
# 6436: Virgin_17
# 8787: BMW_3_Series_(E30)
# 10303: Harriet_Craig
# 3702: Lee_Pressman
# 3012: Godfrey_Cambridge
# 8121: Helter_Skelter_(book)
# 6220: Hope_Lange
# 8041: The_Darling_Buds_of_May_(TV_series)
# 2654: Frank_Borman
# 7564: Richard_Matheson
# 5607: USSR_State_Prize
# 6181: Grover_Cleveland
# 6: Donald_B._Beary
# 9777: First_of_the_Summer_Wine
# 6483: Newsweb_Corporation
# 4927: Kevin_Amuneke
# 111: Baltimore
# 9248: Charles_A._Smith_(architect)
# 8517: G._V._Prakash_Kumar
# 4538: Wales_national_football_team
# 5757: Steven_V._Ley
# 1795: Walter_Kohn
# 9666: Dick_Jones_(actor)
# 7458: John_H._Corcoran
# 29: Li_Yapeng
# 6340: Worldvision_Enterprises
# 2795: Geoffrey_Castillion
# 1239: Yitang_Zhang
# 5005: FC_Volyn_Lutsk
# 7768: Liberal_Party_of_Canada
# 7180: NBC
# 4787: Bolton_Wanderers_F.C.
# 1108: Amanda_Peet
# 8616: Paul_Armin_Due
# 3924: University_of_California,_Berkeley
# 2243: Eugene_Wigner
# 7646: Lothar_Bisky
# 897: D._LeRoy_Dresser
# 5531: Hero_of_Socialist_Labour
# 1604: Konrad_Wolff
# 619: Carl_Van_Vechten
# 10529: Monster_House_(film)
# 5305: IEEE_Edison_Medal
# 1160: Alice_Hamilton
# 2374: Giuditta_Rissone
# 4179: University_of_Padua
# 3985: MIT_Sloan_School_of_Management
# 8058: Series_30+
# 679: Ponce,_Puerto_Rico
# 5140: SD_Eibar
# 7698: Liberal_Party_(Philippines)
# 547: Joi_Lansing
# 4657: Kingstonian_F.C.
# 3092: James_Rowell
# 8913: La_Dolce_Vita
# 4836: Ben_Alnwick
# 6157: Li_Jinhui
# 712: Gordon_Prentice
# 7331: World_Wrestling_Network
# 4096: University_of_Texas_Health_Science_Center_at_San_Antonio
# 833: Grigory_Margulis
# 7531: John_Boyland
# 3141: Lee_Keun-ho
# 1294: Ian_Chubb
# 774: Benedict_Zilliacus
# 4169: University_of_Leeds
# 10222: CA_Harvest_Software_Change_Manager
# 4147: DuPont
# 4059: Purdue_University
# 3015: Krishna_(TV_actor)
# 4659: Ahmed_Deen
# 5506: Roger_Penrose
# 7528: Jesse_Helms
# 8809: Elliot_Lawrence
# 6676: Government_of_Serbia
# 352: Ian_Keith
# 1453: Michael_Weatherly
# 6443: Caisse_de_dépôt_et_de_gestion
# 9843: Interpreter_of_Maladies
# 10574: Justice_League_Unlimited
# 2162: Canada
# 463: Saint_Petersburg
# 573: Kolkata
# 2006: Andrew_Miller_(actor)
# 7466: Robert_A._Dahl
# 4110: National_University_of_Singapore
# 1068: Andrew_Marr
# 7090: NEC
# 4594: José_Soares
# 1337: Agrigento
# 2679: Eugene_(actress)
# 5460: Guy_Medal
# 1401: Sherman_Oaks,_Los_Angeles
# 7296: Generali_Italia
# 8060: Ryan_Nagode
# 6364: ATV_(Austria)
# 10306: The_Conformist
# 2888: Tom_Noonan
# 86: Waterbury,_Connecticut
# 9932: Tigervision
# 6316: Jan_Clayton
# 5866: George_S._Hammond
# 1757: Carly_Chaikin
# 10468: Ansiba_Hassan
# 5600: Kavli_Prize
# 582: Watford
# 5748: Ronald_Drever
# 3227: Hugh_Parker_Guiler
# 3045: Gerald_Estrin
# 187: Sarajevo
# 5707: Breakthrough_Prize_in_Life_Sciences
# 3345: Teresa_Wright
# 3940: Oregon_State_University
# 6595: Ack_Ack_(horse)
# 5453: TWAS_Prize
# 7456: City_College_of_New_York
# 812: Geelong
# 4817: Dundee_United_F.C.
# 3928: Carlos_E._Chardón
# 3200: Dino_Andrade
# 10522: Dressed_to_Kill_(1980_film)
# 3196: Bob_Maclennan,_Baron_Maclennan_of_Rogart
# 8723: Benjamin_Henry_Latrobe
# 4364: Beitar_Jerusalem_F.C.
# 9694: James_Horner
# 7784: George_Foley
# 3618: Allison_Munn
# 327: Mark_Kelly
# 9215: Sheffield_Cathedral
# 6926: London_Borough_of_Merton
# 3653: Marie-Hélène_de_Rothschild
# 255: Kay_Thompson
# 2089: Donald_Tusk
# 1300: Robert_Culp
# 8416: Robert_Speechly
# 1214: Rove_McManus
# 9944: Still_Alice_(novel)
# 7842: New_Progressive_Party_(South_Korea)
# 997: Enrico_Coen
# 5562: Kistler_Prize
# 8093: The_Bacchae
# 4815: Hertha_BSC
# 10462: The_Territorial_Imperative
# 1052: Staten_Island
# 1821: Svante_Pääbo
# 4069: Ian_Graham_Gass
# 5170: Dan_David_Prize
# 9467: Fiat_Barchetta
# 1114: Mozelle_Britton
# 1883: Alec_Jeffreys
# 7272: Compañía_Española_de_Petróleos
# 7758: William_Alexander_Graham
# 764: Belfast
# 4625: Alessio_Cerci
# 7766: John_Forrest
# 817: Jorge_Madureira
# 5877: Sewall_Wright
# 1502: Hong_Sehwa
# 4567: Albacete_Balompié
# 10421: Mario_Bellini
# 9803: Bejeweled_2
# 1773: James_B._Donovan
# 10431: The_Power_of_Now
# 6847: Cadillac_Fairview
# 8074: The_Mambo_Kings_Play_Songs_of_Love
# 682: Eamonn_O'Keefe
# 2843: Richard_Marx
# 8586: Logic_Works
# 1022: Kathy_Najimy
# 922: Luke_Bullen
# 1945: Dhaka
# 10086: Lauren_Manning
# 6303: Dorothy_Ayer_Gardner_Ford
# 2705: Vidal_Sassoon
# 7478: Charles_Fahy
# 9575: Jack_Park
# 756: Teri_Hatcher
# 10466: House_of_Shennib
# 9831: American_Institute_of_Architects

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/hyte_relation2id.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# <wasBornIn>	0
# <diedIn>	7
# <worksAt>	1
# <playsFor>	2
# <hasWonPrize>	3
# <isMarriedTo>	4
# <owns>	5
# <graduatedFrom>	6
# <isAffiliatedTo>	8
# <created>	9

# %%
def create_mapping(input_file_path):
    mapping = {}

    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    for line in lines:
        # Split the line by tabs
        elements = line.strip().split('\t')

        # Extract the integer and name
        integer = int(elements[1])
        name = elements[0].replace('<', '').replace('>', '')

        # Add to the mapping
        mapping[integer] = name

    return mapping

# Example usage
input_file_path = '/content/drive/MyDrive/hyte_relation2id.txt'  # Replace with your actual input file path

relation_mapping = create_mapping(input_file_path)

# Print or use the resulting mapping as needed
print("Mapping of integers to names:")
for integer, name in relation_mapping.items():
    print(f"{integer}: {name}")
# Out:
# Mapping of integers to names:
# 0: wasBornIn
# 7: diedIn
# 1: worksAt
# 2: playsFor
# 3: hasWonPrize
# 4: isMarriedTo
# 5: owns
# 6: graduatedFrom
# 8: isAffiliatedTo
# 9: created

# %%
relation_mapping
# Out:
# {0: 'wasBornIn',
#  7: 'diedIn',
#  1: 'worksAt',
#  2: 'playsFor',
#  3: 'hasWonPrize',
#  4: 'isMarriedTo',
#  5: 'owns',
#  6: 'graduatedFrom',
#  8: 'isAffiliatedTo',
#  9: 'created'}

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/hyte_triple2id.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# 0	0	1	1945-11-07	1945-11-07
# 2	0	3	1948-03-31	1948-03-31
# 4	0	5	1952-05-14	1952-05-14
# 6	0	7	1888-12-04	1888-12-04
# 8	0	9	1910-07-17	1910-07-17
# 10	0	11	1983-02-08	1983-02-08
# 12	0	13	1983-07-07	1983-07-07
# 14	0	15	1914-08-30	1914-08-30
# 16	0	17	1975-01-05	1975-01-05
# 18	0	11	1985-09-17	1985-09-17
# 19	0	20	1915-06-30	1915-06-30
# 21	0	22	1929-08-06	1929-08-06
# 23	0	24	1860-09-29	1860-09-29
# 25	0	26	1969-01-19	1969-01-19
# 27	0	28	1872-08-02	1872-08-02

# %%
def replace_ids_with_entities_relations(input_file_path, output_file_path, entity_mapping, relation_mapping):
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    with open(output_file_path, 'w') as output_file:
        for line in lines:
            elements = line.strip().split('\t')

            # Replace entity IDs with actual entities
            entity_id_1 = int(elements[0])
            entity_id_2 = int(elements[2])

            if entity_id_1 in entity_mapping:
                elements[0] = entity_mapping[entity_id_1]

            if entity_id_2 in entity_mapping:
                elements[2] = entity_mapping[entity_id_2]

            # Replace relation IDs with actual relations
            relation_id = int(elements[1])
            if relation_id in relation_mapping:
                elements[1] = relation_mapping[relation_id]

            # Write the modified line to the output file
            output_file.write('\t'.join(elements) + '\n')

# Example usage
input_file_path = '/content/drive/MyDrive/hyte_triple2id.txt'  # Replace with your actual input file path
output_file_path = '/content/drive/MyDrive/hyte_text_data.txt'  # Replace with your desired output file path


replace_ids_with_entities_relations(input_file_path, output_file_path, entity_mapping, relation_mapping)

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/hyte_text_data.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# Beverly_Adams	wasBornIn	Edmonton	1945-11-07	1945-11-07
# Al_Gore	wasBornIn	Washington,_D.C.	1948-03-31	1948-03-31
# Donald_R._McMonagle	wasBornIn	Flint,_Michigan	1952-05-14	1952-05-14
# Donald_B._Beary	wasBornIn	Helena,_Montana	1888-12-04	1888-12-04
# Ida_Halpern	wasBornIn	Vienna	1910-07-17	1910-07-17
# João_Paiva	wasBornIn	Lisbon	1983-02-08	1983-02-08
# Vincent_Wong_(Hong_Kong_actor)	wasBornIn	Hong_Kong	1983-07-07	1983-07-07
# Julie_Bishop_(actress)	wasBornIn	Denver	1914-08-30	1914-08-30
# Bradley_Cooper	wasBornIn	Philadelphia	1975-01-05	1975-01-05
# José_Gonçalves_(footballer)	wasBornIn	Lisbon	1985-09-17	1985-09-17
# Harry_Weese	wasBornIn	Evanston,_Illinois	1915-06-30	1915-06-30
# Roger_MacBride	wasBornIn	New_Rochelle,_New_York	1929-08-06	1929-08-06
# James_Neill	wasBornIn	Savannah,_Georgia	1860-09-29	1860-09-29
# Wendy_Moniz	wasBornIn	Kansas_City,_Missouri	1969-01-19	1969-01-19
# Rob_Wagner	wasBornIn	Detroit	1872-08-02	1872-08-02

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/filtered_literal_data.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# Jens_Petersen	wasBornOnDate	1941
# Avery_Brundage	diedOnDate	1975
# Werner_Herzog	wasBornOnDate	1942
# Ngaio_Marsh	wasCreatedOnDate	2010
# Layne_Staley	wasDestroyedOnDate	1987
# Anne_of_Austria,_Queen_of_Poland	diedOnDate	1598
# Alessandro_Manzoni	diedOnDate	1873
# Cornelius_Castoriadis	wasCreatedOnDate	2000
# Bradley_Bell	wasBornOnDate	1964
# Joseph_Jackson_(screenwriter)	wasBornOnDate	1894
# Sidney_Luft	diedOnDate	2005
# Dewi_Zephaniah_Phillips	diedOnDate	2006
# Erskine_Hamilton_Childers	diedOnDate	1974
# Luigi_Ferrero	wasBornOnDate	1904
# John_Fante	diedOnDate	1983

# %%
# Specify the file path
file_path = '/content/drive/MyDrive/TEMPORAL_filtered_literal_data.txt'

# Specify the number of lines to read
num_lines_to_read = 15

# Open the file in read mode ('r')
with open(file_path, 'r') as file:
    # Read the specified number of lines
    for _ in range(num_lines_to_read):
        line = file.readline()

        # Check if the line is not empty (end of file)
        if not line:
            break

        # Process or print the line
        print(line.strip())
# Out:
# Jens_Petersen	wasBornOnDate	1941	1941	1941
# Avery_Brundage	diedOnDate	1975	1975	1975
# Werner_Herzog	wasBornOnDate	1942	1942	1942
# Ngaio_Marsh	wasCreatedOnDate	2010	2010	2010
# Layne_Staley	wasDestroyedOnDate	1987	1987	1987
# Anne_of_Austria,_Queen_of_Poland	diedOnDate	1598	1598	1598
# Alessandro_Manzoni	diedOnDate	1873	1873	1873
# Cornelius_Castoriadis	wasCreatedOnDate	2000	2000	2000
# Bradley_Bell	wasBornOnDate	1964	1964	1964
# Joseph_Jackson_(screenwriter)	wasBornOnDate	1894	1894	1894
# Sidney_Luft	diedOnDate	2005	2005	2005
# Dewi_Zephaniah_Phillips	diedOnDate	2006	2006	2006
# Erskine_Hamilton_Childers	diedOnDate	1974	1974	1974
# Luigi_Ferrero	wasBornOnDate	1904	1904	1904
# John_Fante	diedOnDate	1983	1983	1983

# %%
def combine_files(file1_path, file2_path, output_file_path):
    with open(file1_path, 'r') as file1, open(file2_path, 'r') as file2:
        content1 = file1.read()
        content2 = file2.read()

    combined_content = content1 + content2

    with open(output_file_path, 'w') as output_file:
        output_file.write(combined_content)

# Example usage
file1_path = '/content/drive/MyDrive/hyte_text_data.txt'  # Replace with your actual file1 path
file2_path = '/content/drive/MyDrive/TEMPORAL_filtered_literal_data.txt'  # Replace with your actual file2 path
output_file_path = '/content/drive/MyDrive/combined_data.txt'  # Replace with your desired output file path

combine_files(file1_path, file2_path, output_file_path)

# %%
# Input file path
input_file_path = '/content/drive/MyDrive/combined_data.txt'

# Output file path
output_file_path = '/content/drive/MyDrive/comb_entity2id.txt'

# Dictionary to store unique values and corresponding integers
unique_values_dict = {}

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            first_element = elements[0]

            # If the value is not in the dictionary, add it with a unique integer
            if first_element not in unique_values_dict:
                unique_values_dict[first_element] = len(unique_values_dict)

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            third_element = elements[2]

            # If the value is not in the dictionary, add it with a unique integer
            if third_element not in unique_values_dict:
                unique_values_dict[third_element] = len(unique_values_dict)

# Write unique values with <> symbols and unique integers to the output file
with open(output_file_path, 'w') as output_file:
    for value, unique_integer in unique_values_dict.items():
        output_file.write(f'<{value}>  \t{unique_integer}\n')

# %%
# Input file path
input_file_path = '/content/drive/MyDrive/combined_data.txt'

# Output file path
output_file_path = '/content/drive/MyDrive/USE_comb_entity2id.txt'

# Dictionary to store unique values and corresponding integers
unique_values_dict = {}

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            first_element = elements[0]

            # If the value is not in the dictionary, add it with a unique integer
            if first_element not in unique_values_dict:
                unique_values_dict[first_element] = len(unique_values_dict)

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            third_element = elements[2]

            # If the value is not in the dictionary, add it with a unique integer
            if third_element not in unique_values_dict:
                unique_values_dict[third_element] = len(unique_values_dict)

# Write unique values with <> symbols and unique integers to the output file
with open(output_file_path, 'w') as output_file:
    for value, unique_integer in unique_values_dict.items():
        output_file.write(f'{value}  \t{unique_integer}\n')

# %%
# Input file path
input_file_path = '/content/drive/MyDrive/combined_data.txt'

# Output file path
output_file_path = '/content/drive/MyDrive/comb_relation2id.txt'

# Dictionary to store unique values and corresponding integers
unique_values_dict = {}

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            second_element = elements[1]

            # If the value is not in the dictionary, add it with a unique integer
            if second_element not in unique_values_dict:
                unique_values_dict[second_element] = len(unique_values_dict)

# Write unique values with <> symbols and unique integers to the output file
with open(output_file_path, 'w') as output_file:
    for value, unique_integer in unique_values_dict.items():
        output_file.write(f'<{value}>  \t{unique_integer}\n')

# %%
# Input file path
input_file_path = '/content/drive/MyDrive/combined_data.txt'

# Output file path
output_file_path = '/content/drive/MyDrive/USE_comb_relation2id.txt'

# Dictionary to store unique values and corresponding integers
unique_values_dict = {}

# Read the input file and extract unique values
with open(input_file_path, 'r') as input_file:
    for line in input_file:
        # Split the line into elements
        elements = line.strip().split()

        # Check if there's at least one element
        if elements:
            # Extract the first element
            second_element = elements[1]

            # If the value is not in the dictionary, add it with a unique integer
            if second_element not in unique_values_dict:
                unique_values_dict[second_element] = len(unique_values_dict)

# Write unique values with <> symbols and unique integers to the output file
with open(output_file_path, 'w') as output_file:
    for value, unique_integer in unique_values_dict.items():
        output_file.write(f'{value}  \t{unique_integer}\n')

# %%
entity2id_path = '/content/drive/MyDrive/USE_comb_entity2id.txt'
relation2id_path = '/content/drive/MyDrive/USE_comb_relation2id.txt'

# Read entity2id and relation2id mappings
entity_mapping = {}
relation_mapping = {}

with open(entity2id_path, 'r') as entity_file:
    for line in entity_file:
        parts = line.strip().split('\t')
        if len(parts) == 2:
            entity_mapping[parts[0].strip()] = parts[1]

with open(relation2id_path, 'r') as relation_file:
    for line in relation_file:
        parts = line.strip().split('\t')
        if len(parts) == 2:
            relation_mapping[parts[0].strip()] = parts[1]

# %%
def map_values_to_names(input_file_path, output_file_path, entity_mapping, relation_mapping):
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    with open(output_file_path, 'w') as output_file:
        for line in lines:
            elements = line.strip().split('\t')
            if len(elements) >= 3:
                # Replace entity values in the 1st and 3rd columns
                entity1 = entity_mapping.get(elements[0], elements[0])
                entity2 = entity_mapping.get(elements[2], elements[2])

                # Replace relation value in the 2nd column
                relation = relation_mapping.get(elements[1], elements[1])

                # Keep the 4th and 5th columns unchanged
                output_line = f"{entity1}\t{relation}\t{entity2}\t{elements[3]}\t{elements[4]}\n"

                output_file.write(output_line)

# Example usage
input_file_path = '/content/drive/MyDrive/combined_data.txt'  # Replace with your actual input file path
output_file_path = '/content/drive/MyDrive/combined_triple2id.txt'  # Replace with your desired output file path


map_values_to_names(input_file_path, output_file_path, entity_mapping, relation_mapping)

# %%
def map_values_to_names(input_file_path, output_file_path, entity_mapping, relation_mapping):
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    with open(output_file_path, 'w') as output_file:
        for line in lines:
            elements = line.strip().split('\t')
            if len(elements) >= 3:
                # Replace entity values in the 1st and 3rd columns
                entity1 = entity_mapping.get(elements[0], elements[0])
                entity2 = entity_mapping.get(elements[2], elements[2])

                # Replace relation value in the 2nd column
                relation = relation_mapping.get(elements[1], elements[1])

                # Keep the 4th and 5th columns unchanged
                output_line = f"{entity1}\t{relation}\t{entity2}\t{elements[3]}\t{elements[4]}\n"

                output_file.write(output_line)

# Example usage
input_file_path = '/content/drive/MyDrive/combined_data.txt'  # Replace with your actual input file path
output_file_path = '/content/drive/MyDrive/COPY_combined_triple2id.txt'  # Replace with your desired output file path


map_values_to_names(input_file_path, output_file_path, entity_mapping, relation_mapping)

# %% [markdown]
# # **SHUFFLING**

# %%
import random

def shuffle_lines(input_file_path, output_file_path):
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()
        random.shuffle(lines)

    with open(output_file_path, 'w') as output_file:
        output_file.writelines(lines)

# Example usage
input_file_path = '/content/drive/MyDrive/COPY_combined_triple2id.txt'  # Replace with your actual input file path
output_file_path = '/content/drive/MyDrive/COPY_combined_triple2id.txt' # Replace with your desired output file path

shuffle_lines(input_file_path, output_file_path)

# %% [markdown]
# # **TRAIN_SPLIT**

# %%
def create_training_set_and_remove(input_file_path, train_file_path):
    # Read the content of the input file
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    # Extract unique values from the first column and the third column:
    unique_values = set()
    for line in lines:
        elements = line.strip().split('\t')
        if len(elements) >= 4:
            unique_values.add(elements[0])
            unique_values.add(elements[2])

    # Initialize the training set and set to track included values
    training_set = []
    included_values = set()

    # Iterate through lines to create the training set
    for line in lines:
        value1 = line.split()[0]
        value2 = line.split()[2]

        # Include the line in the training set if it has a unique value
        if value1 in unique_values and value1 not in included_values:
            training_set.append(line)
            included_values.add(value1)
            included_values.add(value2)

        if value2 in unique_values and value2 not in included_values:
            training_set.append(line)
            included_values.add(value1)
            included_values.add(value2)


    # Write the training set to the training file
    with open(train_file_path, 'w') as train_file:
        train_file.writelines(training_set)

    # Remove included data points from the input file
    lines = [line for line in lines if line not in training_set]
    with open(input_file_path, 'w') as input_file:
        input_file.writelines(lines)

# Define file paths
# Define file paths
input_file_path = '/content/drive/MyDrive/COPY_combined_triple2id.txt'
train_file_path = '/content/drive/MyDrive/train_data.txt'

# Create the training set and remove data points from the input file
create_training_set_and_remove(input_file_path, train_file_path)

# %%
def find_lines_with_condition(input_file_path):
    # Read the content of the input file
    with open(input_file_path, 'r') as input_file:
        lines = input_file.readlines()

    # Identify line numbers where the 3rd element has length != 4
    lines_with_condition = []
    for i, line in enumerate(lines):
        elements = line.strip().split('\t')
        if len(elements[2]) > 5:
            lines_with_condition.append(i + 1)  # Adding 1 to convert from zero-based index to line number

    return lines_with_condition

# Define file path
input_file_path = '/content/drive/MyDrive/combined_triple2id.txt'

# Find line numbers where the 3rd element has length != 5
lines_with_condition = find_lines_with_condition(input_file_path)

# %%
lines_with_condition
# Out:
# []
